# %% [markdown]
# # Wordcloud of _whoami_

# %%
# imports
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Read the whole text
with open('../data/whoami', 'r') as f:
    text = f.read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
#wordcloud = WordCloud(max_font_size=40).generate(text)
#plt.figure()
#plt.imshow(wordcloud, interpolation="bilinear")
#plt.axis("off")
plt.show()

# %%
width_ratio = 6.2
height_ratio = 5.6

y = 400 * 5.6 / 6.2
y
# Out:
# 361.2903225806451

# %%
# define the wordcloud
wordcloud = WordCloud(max_font_size=50,
                      background_color='#EEEEEE',
                      prefer_horizontal=0.9,
                      width=400,
                      height=361).generate(text)

# create the figure
fig, ax = plt.subplots(figsize=(10,10))

# plot the wordcloud
ax.imshow(wordcloud, interpolation='spline36')
ax.axis("off")

plt.show()

# %%
wordcloud.to_file("../images/whoami.png")

# %%
x = 1.2
400 * x, 361 * x
# Out:
# (480.0, 433.2)
